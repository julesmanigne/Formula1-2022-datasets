# %%
# Formula 1 - 2022 Season Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
from datetime import timedelta
# %matplotlib inline

# %%
calendar = pd.read_csv('F1-2022_calendar.csv')
calendar.set_index('Round', inplace=True)

# %%
raceResults = pd.read_csv('F1-2022_raceResults.csv')

# %%
sprintResults = pd.read_csv('F1-2022_sprintResults.csv')

# %%
qualifyingResults = pd.read_csv('F1-2022_qualifyingResults.csv')

# %%
calendar[['GP Name', 'Country', 'City', 'Circuit Name', 'Race Date', 'Circuit Length(km)', 'Number of Laps','Race Distance(km)']]
# Out:
#                GP Name        Country         City  \
# Round
# 1           Bahrain GP        Bahrain       Sakhir
# 2      Saudi Arabia GP   Saudi Arabia       Jeddah
# 3         Australia GP      Australia    Melbourne
# 4       Emilia Romagna          Italy        Imola
# 5             Miami GP  United States        Miami
# 6             Spain GP          Spain    Catalunya
# 7            Monaco GP         Monaco  Monte Carlo
# 8        Azerbaijan GP     Azerbaijan         Baku
# 9            Canada GP         Canada     Montreal
#
#                          Circuit Name    Race Date  Circuit Length(km)  \
# Round
# 1       Bahrain International Circuit  20 Mar 2022               5.412
# 2             Jeddah Corniche Circuit  27 Mar 2022               6.174
# 3                 Albert Park Circuit  10 Apr 2022               5.278
# 4       Autodromo Enzo e Dino Ferrari  24 Apr 2022               4.909
# 5       Miami International Autodrome   8 May 2022               5.412
# ...
